# %% [markdown]
# <a href="https://colab.research.google.com/github/youngwoonjeong/PythonClass/blob/main/20211102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-e8326a161779> in <module>()
# ----> 1 2/0
#
# ZeroDivisionError: division by zero

# %%
a = int(input('제수를 입력하세요 >>>'))
b = int(input('피제수를 입력하세요 >>>'))

if b == 0:
  print('0으로 나누는 것은 불가능합니다.')
else:
  print('{}/{} = {}'.format(a,b,a/b))
# Out:
# 제수를 입력하세요 >>>3
# 피제수를 입력하세요 >>>0
# 0으로 나누는 것은 불가능합니다.

# %%
try:
  a = int(input('제수를 입력하세요 >>>'))
  b = int(input('피제수를 입력하세요 >>>'))
  print('{}/{} = {}'.format(a,b,a/b))
except:
  print('에러가 발생했습니다.')
# Out:
# 제수를 입력하세요 >>>3.6
# 에러가 발생했습니다.

# %%
try:
  height = input('키를 입력하세요 >>>')
  height = round(height)   # 반올림
  print('입력하신 키는 {}cm로 처리됩니다.'.format(height))
except:
  print('예외가 발생했습니다.')
# Out:
# 키를 입력하세요 >>>176.6
# 예외가 발생했습니다.

# %%
try:
  a = int(input('제수를 입력하세요 >>>'))
  b = int(input('피제수를 입력하세요 >>>'))
  print('{}/{} = {}'.format(a,b,a/b))
except ZeroDivisionError:
  print('0으로 나눌 수 없습니다.')
except ValueError:
  print('정수만 입력할 수 있습니다.')
finally:
  print('프로그램 종료')
# Out:
# 제수를 입력하세요 >>>4
# 피제수를 입력하세요 >>>0
# 0으로 나눌 수 없습니다.
# 프로그램 종료

# %%
a = [10,20,30,40,50]

try:
  a[10]
except IndexError as e:
  print(e)
# Out:
# list index out of range

# %%
try:
  filemane = input('열고자 하는 파일명을 입력하세요. >>>')
  file = open(filename,'rt')
except FileNotFoundError:
  print('{}파일이 존재하지 않습니다.'.format(filename))
else:
  buffer = file.read()
  print(buffer,end='')
  print()
  file.close()
finally:
  print('프로그램을 종료합니다.')
# Out:
# 열고자 하는 파일명을 입력하세요. >>>'rt'
# 프로그램을 종료합니다.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-fef89038108c> in <module>()
#       1 try:
#       2   filemane = input('열고자 하는 파일명을 입력하세요. >>>')
# ----> 3   file = open(filename,'rt')
#       4 except FileNotFoundError:
#       5   print('{}파일이 존재하지 않습니다.'.format(filename))
#
# NameError: name 'filename' is not defined

# %%
try:
  score = int(input('점수를 입력하세요. >>>'))
  if score < 0 or score > 100:
    raise Exception('점수는 0~100 사이입니다.')
except Exception as e:
  print(e)
else:
  if score >= 80:
    print('{}점은 합격입니다.'.format(score))
  else:
    print('{}점은 불합격입니다.'.format(score))
# Out:
# 점수를 입력하세요. >>>-30
# 점수는 0~100 사이입니다.

# %%
# 예외처리 = 오류, 에러 등을 처리, 처리는 에러를 고치는 게 아닌 적절한 조치를 취한다.


f = open("NONE"."r")
# Out:
#   File "<ipython-input-27-101660d3846b>", line 4
#     f = open("NONE"."r")
#                       ^
# SyntaxError: invalid syntax

# %%
try:
  a = [1,2]
  print(a[3])
  4/0
except ZeroDivisionError:
  print('0으로 나눌 수 없습니다.')
except IndexError:
  print('인덱스 에러입니다.')
finally:
  print('프로그램을 종료합니다.')
# Out:
# 인덱스 에러입니다.
# 프로그램을 종료합니다.

# %%
try:
  a = [1,2]
  print(a[3])
  4/0
except (ZeroDivisionError,IndexError) as e:
  print(e)

finally:
  print('프로그램을 종료합니다.')
# Out:
# list index out of range
# 프로그램을 종료합니다.

# %%
try:
  age = int(input('나이를 입력하세요. >>> '))
except:
  print('입력이 정확하지 않습니다.')
else:
  if age <=18:
    print('민짜임')
  else:
    print('성인임')
# Out:
# 나이를 입력하세요. >>> 18.5
# 입력이 정확하지 않습니다.

# %%
try:
  4/0
except:
  pass

# %%
class Bird:
  def fly(self):
    raise NotImplementedError           # NotImplementedError 꼭 만들어라 라는 에러

# %%
class Eagle(Bird):
  pass

eagle = Eagle()

eagle.fly()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-38-e7a24cef23f1> in <module>()
#       4 eagle = Eagle()
#       5
# ----> 6 eagle.fly()
#
# <ipython-input-37-69a11743b734> in fly(self)
#       1 class Bird:
#       2   def fly(self):
# ----> 3     raise NotImplementedError           # 꼭 만들어라 라는 에러
#
# NotImplementedError:

# %%
class Eagle(Bird):
  def fly(self):
    print("very fast")

eagle = Eagle()

eagle.fly()
# Out:
# very fast

# %%
class MyError(Exception):
  pass

def say_nick(nick):
  if nick == "바보":
    raise MyError()

# %%
try:
  say_nick("천사")
  say_nick("바보")
except MyError:
  print("허용되지 않는 별명")
# Out:
# 허용되지 않는 별명

# %%
class NameError(Exception):

  def __init__(self,message):
    super().__init__(message)


try:
  name = input('이름을 입력하세요 >>>')
  if len(name) < 2 or len(name) > 6:
    raise NameError('이름은 2~6자 사이로 입력해주세요.')
except NameError as e:
  print(e)
else:
  print('입력된 이름은 {}입니다.'.format(name))
# Out:
# 이름을 입력하세요 >>>김숙
# 입력된 이름은 김숙입니다.

# %%
# !pip install requests    인터넷 연결
# !pip install BeautifulSoup4   크롤링한 데이터 가공

# %%
# HTML(흑백) CSS(컬러) JS(스마트)


import requests

url = 'https://search.naver.com/search.naver?query=애플'
response = requests.get(url)
print('응답코드:{}'.format(response.status_code))
print(response.text)
# Out:
# 응답코드:200
# ...

# %%
import requests

url = 'https://search.naver.com/search.naver'
param = {'query':'아이폰'}
response = requests.get(url, params=param)

print(response.text)
# Out:
# <!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="아이폰 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'아이폰'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="'아이폰'의 네이버 통합검색 결과입니다."> <title>아이폰 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_211021.css"> <link rel="stylesheet" type="text/css" href="h
# ...

# %%
import requests
url= 'https://movie.naver.com/movie/bi/mi/basic.nhn'
param = {'code': 161967}
response = requests.get(url, params=param)
print(response.text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta http-equiv="imagetoolbar" content="no">
# <title>기생충 : 네이버 영화</title>
#
#
#
#
#
#
#
#
#
#
#
#
# <meta property="me2:image" content="https://ssl.pstatic.net/imgmovie/today/naverme/naverme_profile.jpg"/>
# <meta property="me2:post_tag" content="네이버영화 기생충"/>
# <meta property="me2:category1" content="네이버영화"/>
# <meta property="me2:category2" content="기생충"/>
#
#
#
#
#
#
# 		<meta property="og:title" content="기생충"/>
#
#
#
# <meta property="og:type" content="article"/>
#
# <meta property="og:url" content="https://movie.naver.com/movie/bi/mi/basic.naver?code=161967"/>
#
#
#
# 		<meta property="og:image" content="https://movie-phinf.pstatic.net/20190528_36/1559024198386YVTEw_JPEG/movie_image.jpg?type=m665_443_2"/>
#
#
#
#
#
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://search.naver.com/search.naver'
param = {'query':'아이폰'}
response = requests.get(url, params=param)



html = response.text
soup = BeautifulSoup(html, 'html_parser')
# Out:
#   File "<ipython-input-64-cff575cc9d25>", line 11
#     soup = BeautifulSoup(html. 'html_parser')
#                                            ^
# SyntaxError: invalid syntax
